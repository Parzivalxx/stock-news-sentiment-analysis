# %% [markdown]
# # Stock news sentiment analysis

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
finviz_url = "https://finviz.com/quote.ashx?t="

# %%
news_tables = {}
tickers = []
print("Welcome to the stock sentiment analysis program")
print("You may analyse up to 5 different stocks below, enter 1 when done")
time.sleep(0.5)

i = 0
while i < 5:
    ticker = input(f"Please enter stock {i+1}: ")
    if ticker == "1":
        break
    if ticker in tickers:
        print("Error: that stock was already entered, please try again")
        continue
    tickers.append(ticker)
    i += 1

print("Proceeding to analyse...")
time.sleep(1)
# Out:
# Welcome to the stock sentiment analysis program
# You may analyse up to 5 different stocks below, enter 1 when done
# Please enter stock 1: GME
# Please enter stock 2: SLV
# Please enter stock 3: AMC
# Please enter stock 4: 1
# Proceeding to analyse...

# %%
for ticker in tickers:
    print(f"Analysing {ticker}...")
    url = finviz_url + ticker
    req = Request(url=url, headers={'user-agent': 'my-app'})
    response = urlopen(req)
    html = BeautifulSoup(response, features='html.parser')
    news_table = html.find(id='news-table')
    news_tables[ticker] = news_table
# Out:
# Analysing GME...
# Analysing SLV...
# Analysing AMC...

# %%
data = []

for ticker, news_table in news_tables.items():
    for row in news_table.findAll("tr"):
        title = row.a.text
        dateinfo = row.td.text.split()
        if len(dateinfo) == 1:
            time = dateinfo[0]
        else:
            date = dateinfo[0]
            time = dateinfo[1]
        data.append([ticker,date,time,title])

# %%
df = pd.DataFrame(data, columns = ["ticker", "date", "time", "title"])

# %%
vader = SentimentIntensityAnalyzer()

getscorefunc = lambda title: vader.polarity_scores(title)["compound"]

df['compound'] = df['title'].apply(getscorefunc)
df['date'] = pd.to_datetime(df["date"]).dt.date

# %%
mean_df = df.groupby(['ticker', 'date']).mean()
mean_df
# Out:
#                    compound
# ticker date
# AMC    2021-02-04  0.081967
#        2021-02-05 -0.034384
#        2021-02-06 -0.038120
#        2021-02-07  0.048375
#        2021-02-08 -0.018565
# ...                     ...
# SLV    2021-02-02 -0.044433
#        2021-02-03  0.177900
#        2021-02-16  0.000000
#        2021-02-18 -0.128000
#        2021-02-19  0.000000
#
# [90 rows x 1 columns]

# %%
findings_dates = {}
findings_sentiment = {}
tker = ""
i = 0

for finding in mean_df.index.values:
    ticker = finding[0]
    date = finding[1]
    if ticker == tker:
        findings_dates[ticker].append(date)
        findings_sentiment[ticker].append(mean_df.compound[i])
    else:
        tker = ticker
        findings_dates[ticker] = [date]
        findings_sentiment[ticker] = [mean_df.compound[i]]
    i += 1

# %%
for ticker in tickers:
    plt.figure(figsize = (25,10))
    plt.plot(findings_dates[ticker], findings_sentiment[ticker])
    plt.title(ticker)
    plt.xlabel("Dates")
    plt.ylabel("Compound score")
    plt.show()
